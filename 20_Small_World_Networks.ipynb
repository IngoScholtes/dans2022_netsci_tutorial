# %% [markdown]
# # 05-04: Small-world networks
#
# *November 24 2021*
#
# In the final unit of this week we study properties of synthetic and empirical small-world networks and show how we can visualize the property of *shortest path funnelling* using `pathpy`.

# %%
import pathpy as pp
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use('default')
sns.set_style("whitegrid")
# Out:
#     <script charset="utf-8">
#     // Load via requireJS if available (jupyter notebook environment)
#     try {
#     require.config({
#     paths: {
#     d3: "https://d3js.org/d3.v5.min.js".replace(".js", "")
#     }
#     });
#     console.log("OKAY: requireJS was detected");
#     }
#     catch(err){
#     console.log(err);
#     console.log("ERROR: NO requireJS was detected");
#     };
#     require(['d3'], function(d3){
#     console.log("OKAY: d3js was detected");
#     });
#     </script>

# %% [markdown]
# # Shortest Paths in random vs. small-world networks
#
# In the previous practice session, we have seen that many empirical social networks combine a small diameter (or even a small average shortest path length) with a large clustering coefficient, the latter of which we can cannot explain with a simple random graph model. In the lecture, we have further discussed Milgram's experiment, which shows that humans are able to efficiently "navigate" social networks without having global knowledge. To better understand how this works, we have introduced the concept of path funnelling. Let us implement a function that can visualize this in a given network.

# %%
def funelling_plot(n, style={}, layout=None, source=None):
    # visualise number of shortest paths from given node x to all other nodes, passing through neighbors of x
    if source is None:
        source = np.random.choice(list(n.nodes.uids))
        print(source)
    labels = { v: v for v in n.nodes.uids }
    style['node_label_size'] = { v: 2 for v in n.nodes.uids}
    style['node_size'] = { v: 20 for v in n.nodes.uids}
    style['node_color'] = { v: 'CornflowerBlue' for v in n.nodes.uids }
    style['node_color'][source] = 'Red'

    tree = pp.algorithms.shortest_path_tree(n, source=source)
    assert pp.algorithms.check_tree(tree)

    # compute tree size for all neighbors of source
    for v in n.successors[source]:    
        s = pp.algorithms.tree_size(tree, v.uid)
        labels[v.uid] = v.uid + ': ' + str(s)
        style['node_label_size'][v.uid] = 2 + 0.1*s
        style['node_size'][v.uid] = 5 + 2*s
        style['node_color'][v.uid] = 'Green'
    if layout is None:
        layout = pp.layout(n, layout='fr', force=0.5)
    
    n.plot(node_label=labels, node_id_as_label=False, **style, layout=layout)

# %% [markdown]
# For a given source node (shown in red), the function above shows how many shortest paths from this source node to any other node pass through the neighbors of the source node. Let us try this in a Watts-Strogatz network where we rewire all edges with probably 1 (which yields a random graph that is - although not identical to - virtually indistinguishable from a random graph).

# %%
style = {}
style['edge_directed'] = False
style['edge_color'] = 'gray'
style['node_color'] = 'CornflowerBlue'
style['node_label_size'] = 2
style['node_size'] = 20
style['edge_size'] = 1.0

n_random = pp.generators.Watts_Strogatz(n=50, s=2, p=1, loops=False)
funelling_plot(n_random, style)
# Out:
# 18
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="xbbe809da9e4446508076b54a9bf23726"></div>
# <div id="x15b639d5463f4aa0bfc69b8769fe59ce"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 800.0, "height": 550.0, "unit": "px", "dpi": 96, "margin": null, "layout": "euclidean", "temporal": false, "coordinates": true, "euclidean": true, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "forceCharge": -20, "forceRepel": -300, "forceAlpha": 0.1, "restartAlpha": 1, "alphaMin": 0.001, "targetAlpha": 0, "chargeDistance": 800, "repelDistance": 200, "velocityDecay": 0.4, "lookoutStrokeWidth": 1, "lookoutOpacity": 0.5, "lookoutWeight": 0.0, "radiusMinSize": 4, "radiusMaxSize": 16, "nodeTransitionDuration": 100, "defaultEdgeWeight": 1, "targetAlphaDragStarted": 0.3, "targetAlphaDragEnd": 0.0, "linkStrengthMin": 0.0, "linkStrengthMax": 0.45, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "start": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "label_centered": true, "label_enabled": true, "label_color": "white", "curved": false, "directed": false, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": true, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}, "default_node": {"size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true, "coordinates": null}, "default_edge": {"size": 2.0, "color": "black", "opacity": 1, "directed": false, "curved": 0.5}}
#
#  var data = {"nodes": [{"uid": "0", "label": "0", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [295.9041148115868, 83.08301620727974], "label_size": 2, "id_as_label": false}, {"uid": "1", "label": "1", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [541.8533144459872, 360.33799567356823], "label_size": 2, "id_as_label": false}, {"uid": "2", "label": "2", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [435.92188005966966, 108.60135350679275], "label_size": 2, "id_as_label": false}, {"uid": "3", "label": "3", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [486.4426518205865, 175.22177857038457], "label_size": 2, "id_as_label": false}, {"uid": "4", "label": "4", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [438.6611547043157, 269.141863300568], "label_size": 2, "id_as_label": false}, {"uid": "5", "label": "5", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [547.8235860289017, 280.53018491450143], "label_size": 2, "id_as_label": false}, {"uid": "6", "label": "6: 13", "size": 31.0, "color": "Green", "opacity": 0.2, "coordinates": [521.123521551194, 456.3151527112438], "label_size": 3.3, "id_as_label": false}, {"uid": "7", "label": "7", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [496.9235075252021, 355.8046357871568], "label_size": 2, "id_as_label": false}, {"uid": "8", "label": "8", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [356.3134008932757, 104.27993178312619], "label_size": 2, "id_as_label": false}, {"uid": "9", "label": "9", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [519.3865079603868, 25.5], "label_size": 2, "id_as_label": false}, {"uid": "10", "label": "10", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [383.0597391520432, 241.7627944289971], "label_size": 2, "id_as_label": false}, {"uid": "11", "label": "11", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [312.0515282377565, 158.3901852027459], "label_size": 2, "id_as_label": false}, {"uid": "12", "label": "12", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [494.5046452317165, 137.0569139379706], "label_size": 2, "id_as_label": false}, {"uid": "13", "label": "13", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [354.461545916309, 275.7042028670107], "label_size": 2, "id_as_label": false}, {"uid": "14", "label"

# %% [markdown]
# In most realizations, the number of shortest paths passing through each neighbour will be rather similar. This is different for a two-dimensional lattice network with lattice parameter $s>1$. Here two neighbors stand out, as they lie on almost all shortest paths to other nodes. Note that the symmetry is broken due to the odd number of *other* nodes in the network, so there are more nodes on one side of the coordinate space than on the other side.

# %%
n_ring = pp.generators.Watts_Strogatz(n=50, s=2, p=0)
layout = pp.layout(n_ring, layout='lattice', dimension=1)
funelling_plot(n_ring, style, layout)
# Out:
# 3
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="x86b45095b9f343cc91979373b3eaa1fa"></div>
# <div id="xc6a6b8b6e00d402ebecaf1447731d43d"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 800.0, "height": 550.0, "unit": "px", "dpi": 96, "margin": null, "layout": "euclidean", "temporal": false, "coordinates": true, "euclidean": true, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "forceCharge": -20, "forceRepel": -300, "forceAlpha": 0.1, "restartAlpha": 1, "alphaMin": 0.001, "targetAlpha": 0, "chargeDistance": 800, "repelDistance": 200, "velocityDecay": 0.4, "lookoutStrokeWidth": 1, "lookoutOpacity": 0.5, "lookoutWeight": 0.0, "radiusMinSize": 4, "radiusMaxSize": 16, "nodeTransitionDuration": 100, "defaultEdgeWeight": 1, "targetAlphaDragStarted": 0.3, "targetAlphaDragEnd": 0.0, "linkStrengthMin": 0.0, "linkStrengthMax": 0.45, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "start": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "label_centered": true, "label_enabled": true, "label_color": "white", "curved": false, "directed": false, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": true, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}, "default_node": {"size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true, "coordinates": null}, "default_edge": {"size": 2.0, "color": "black", "opacity": 1, "directed": false, "curved": 0.5}}
#
#  var data = {"nodes": [{"uid": "0", "label": "0", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [400.0, 29.5], "label_size": 2, "id_as_label": false}, {"uid": "1", "label": "1: 23", "size": 51.0, "color": "Green", "opacity": 0.2, "coordinates": [430.7693088400367, 31.435840827295692], "label_size": 4.300000000000001, "id_as_label": false}, {"uid": "2", "label": "2: 2", "size": 9.0, "color": "Green", "opacity": 0.2, "coordinates": [461.0533672989718, 37.212833942921065], "label_size": 2.2, "id_as_label": false}, {"uid": "3", "label": "3", "size": 20.0, "color": "Red", "opacity": 0.2, "coordinates": [490.3745776840885, 46.739872714434284], "label_size": 2, "id_as_label": false}, {"uid": "4", "label": "4: 1", "size": 7.0, "color": "Green", "opacity": 0.2, "coordinates": [518.2705269919711, 59.86671004923153], "label_size": 2.1, "id_as_label": false}, {"uid": "5", "label": "5: 23", "size": 51.0, "color": "Green", "opacity": 0.2, "coordinates": [544.3012794378021, 76.38632788095043], "label_size": 4.300000000000001, "id_as_label": false}, {"uid": "6", "label": "6", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [568.0563145054931, 96.0382019680435], "label_size": 2, "id_as_label": false}, {"uid": "7", "label": "7", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [589.1610011014563, 118.51241051669672], "label_size": 2, "id_as_label": false}, {"uid": "8", "label": "8", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [607.2825057107448, 143.45452183265638], "label_size": 2, "id_as_label": false}, {"uid": "9", "label": "9", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [622.1350413804078, 170.4711839207747], "label_size": 2, "id_as_label": false}, {"uid": "10", "label": "10", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [633.4843747504602, 199.13632788095043], "label_size": 2, "id_as_label": false}, {"uid": "11", "label": "11", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [641.1515200538931, 228.99788726920463], "label_size": 2, "id_as_label": false}, {"uid": "12", "label": "12", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [645.0155618291407, 259.5849274555536], "label_size": 2, "id_as_label": false}, {"uid": "13", "label": "13", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [645.0155618291407, 290.41507254444645], "label_size": 2, "id_as_label": false}, {"uid": "14", "label": "1

# %% [markdown]
# If we increase the rewiring probability of the Watts-Strogatz model, this heterogeneity of neighbors is preserved, while -- due to the potential shortcuts introduced with each rewired edge -- the diameter and average shortest path lengths quickly decrease. The resulting funnelling plot now reveals that, in most realizations, there is a clear choice which neighbor we should prefer to contact if we are interested to find a shortest path to any other node in the network.

# %%
n_ws = pp.generators.Watts_Strogatz(n=50, s=4, p=0.075)
funelling_plot(n_ws, style)
# Out:
# 32
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="xc8863b6c679c42e2b0d62cf2780703a7"></div>
# <div id="x0be80ae5171d4d8a91267aacbb3423cf"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 800.0, "height": 550.0, "unit": "px", "dpi": 96, "margin": null, "layout": "euclidean", "temporal": false, "coordinates": true, "euclidean": true, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "forceCharge": -20, "forceRepel": -300, "forceAlpha": 0.1, "restartAlpha": 1, "alphaMin": 0.001, "targetAlpha": 0, "chargeDistance": 800, "repelDistance": 200, "velocityDecay": 0.4, "lookoutStrokeWidth": 1, "lookoutOpacity": 0.5, "lookoutWeight": 0.0, "radiusMinSize": 4, "radiusMaxSize": 16, "nodeTransitionDuration": 100, "defaultEdgeWeight": 1, "targetAlphaDragStarted": 0.3, "targetAlphaDragEnd": 0.0, "linkStrengthMin": 0.0, "linkStrengthMax": 0.45, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "start": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "label_centered": true, "label_enabled": true, "label_color": "white", "curved": false, "directed": false, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": true, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}, "default_node": {"size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true, "coordinates": null}, "default_edge": {"size": 2.0, "color": "black", "opacity": 1, "directed": false, "curved": 0.5}}
#
#  var data = {"nodes": [{"uid": "0", "label": "0", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [581.8647545039903, 200.03941435450935], "label_size": 2, "id_as_label": false}, {"uid": "1", "label": "1", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [497.970980494158, 253.6480377392743], "label_size": 2, "id_as_label": false}, {"uid": "2", "label": "2", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [526.253936592296, 225.21116612985145], "label_size": 2, "id_as_label": false}, {"uid": "3", "label": "3", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [576.9103374493211, 303.77006933513456], "label_size": 2, "id_as_label": false}, {"uid": "4", "label": "4", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [531.4516303234768, 322.00366426802566], "label_size": 2, "id_as_label": false}, {"uid": "5", "label": "5", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [484.72805608047713, 328.70648777802364], "label_size": 2, "id_as_label": false}, {"uid": "6", "label": "6", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [530.9831747723739, 389.65718351626106], "label_size": 2, "id_as_label": false}, {"uid": "7", "label": "7", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [503.69513482305547, 436.6091926765291], "label_size": 2, "id_as_label": false}, {"uid": "8", "label": "8", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [464.2924624551181, 445.2855778499207], "label_size": 2, "id_as_label": false}, {"uid": "9", "label": "9", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [445.04241787080014, 461.5465464579732], "label_size": 2, "id_as_label": false}, {"uid": "10", "label": "10", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [457.9760326916559, 510.47178951461797], "label_size": 2, "id_as_label": false}, {"uid": "11", "label": "11", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [407.20558123470727, 529.5], "label_size": 2, "id_as_label": false}, {"uid": "12", "label": "12", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [419.9429120454421, 453.07170258375044], "label_size": 2, "id_as_label": false}, {"uid": "13", "label": "13", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [351.8341365757617, 466.31309480429576], "label_size": 2, "id_as_label": false}, {"uid": "

# %% [markdown]
# # Empirical small-world networks
#
# We finally test for which of the three empirical networks we find a small-world property. For this, we compare their average shortest path lengths and clustering coefficients to that of random networks with the same macrostate. If the average shortest path lengths are similar to that of a random network (or even smaller) and the clustering coefficient is much larger than expected at random, we call the network a small-world network.

# %%
n_gentoo = pp.io.sql.read_network('../data/networks.db', sql='SELECT DISTINCT source, target FROM gentoo', directed=False, loops=False).largest_connected_component()
n_highschool = pp.io.sql.read_network('../data/networks.db', sql='SELECT DISTINCT source, target FROM highschool', directed=False, loops=False).largest_connected_component()
n_lotr = pp.io.sql.read_network('../data/networks.db', sql='SELECT DISTINCT source, target FROM lotr', directed=False, loops=False).largest_connected_component()
# Out:
# [11-23 17:04:33: WARNING] 154 edges existed already and were not be considered. To capture those edges, consider creating a multiedge and/or directed network.
# [11-23 17:04:33: WARNING] 67 edges existed already and were not be considered. To capture those edges, consider creating a multiedge and/or directed network.

# %%
r_gentoo = pp.generators.ER_np_randomize(n_gentoo).largest_connected_component()

print('cc_e = ', pp.statistics.avg_clustering_coefficient(n_gentoo))
print('cc_r = ', pp.statistics.avg_clustering_coefficient(r_gentoo))
print('<l_e> = ', pp.algorithms.avg_path_length(n_gentoo))
print('<l_r> = ', pp.algorithms.avg_path_length(r_gentoo))
# Out:
# cc_e =  0.017357355654577637
# cc_r =  0.0050450450450450456
# <l_e> =  3.1096379146451367
# <l_r> =  6.079381820845235

# %%
r_highschool = pp.generators.ER_np_randomize(n_highschool).largest_connected_component()

print('cc_e = ', pp.statistics.avg_clustering_coefficient(n_highschool))
print('cc_r = ', pp.statistics.avg_clustering_coefficient(r_highschool))
print('<l_e> = ', pp.algorithms.avg_path_length(n_highschool))
print('<l_r> = ', pp.algorithms.avg_path_length(r_highschool))
# Out:
# cc_e =  0.446799543049543
# cc_r =  0.034662698412698416
# <l_e> =  5.362745098039215
# <l_r> =  3.026050420168067

# %%
r_lotr = pp.generators.ER_np_randomize(n_lotr).largest_connected_component()

print('cc_e = ', pp.statistics.avg_clustering_coefficient(n_lotr))
print('cc_r = ', pp.statistics.avg_clustering_coefficient(r_lotr))
print('<l_e> = ', pp.algorithms.avg_path_length(n_lotr))
print('<l_r> = ', pp.algorithms.avg_path_length(r_lotr))
# Out:
# cc_e =  0.5848854454659764
# cc_r =  0.07282241707175861
# <l_e> =  2.6724273369992146
# <l_r> =  2.399169565705308

# %% [markdown]
# How does the small-world property of the Lord of the Rings character network translate to funnelling? To check this, we can create the shortest path funnelling plot for Samwise Gamgee, which reveals that Gandalfs and Aragon are the two neighbors through which on a majority of the shortest paths from Sam to any other node.

# %%
funelling_plot(n_lotr, source='Sam')
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="xdbd5fcda46f44beea422fbc3c7f2337f"></div>
# <div id="x40b06d75e425481fb5d2dcbc96be031d"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 800.0, "height": 550.0, "unit": "px", "dpi": 96, "margin": null, "layout": "euclidean", "temporal": false, "coordinates": true, "euclidean": true, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "forceCharge": -20, "forceRepel": -300, "forceAlpha": 0.1, "restartAlpha": 1, "alphaMin": 0.001, "targetAlpha": 0, "chargeDistance": 800, "repelDistance": 200, "velocityDecay": 0.4, "lookoutStrokeWidth": 1, "lookoutOpacity": 0.5, "lookoutWeight": 0.0, "radiusMinSize": 4, "radiusMaxSize": 16, "nodeTransitionDuration": 100, "defaultEdgeWeight": 1, "targetAlphaDragStarted": 0.3, "targetAlphaDragEnd": 0.0, "linkStrengthMin": 0.0, "linkStrengthMax": 0.45, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "start": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "label_centered": true, "label_enabled": true, "label_color": "white", "curved": false, "directed": false, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": true, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}, "default_node": {"size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true, "coordinates": null}, "default_edge": {"size": 2.0, "color": "black", "opacity": 1, "directed": false, "curved": 0.5}}
#
#  var data = {"nodes": [{"uid": "Bilbo", "label": "Bilbo: 4", "size": 13.0, "color": "Green", "opacity": 0.2, "coordinates": [345.768576926154, 273.20077497412785], "label_size": 2.4, "id_as_label": false}, {"uid": "Elrond", "label": "Elrond: 25", "size": 55.0, "color": "Green", "opacity": 0.2, "coordinates": [395.0032385144514, 263.7049300928259], "label_size": 4.5, "id_as_label": false}, {"uid": "Sauron", "label": "Sauron", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [387.98342972283, 303.80799188472247], "label_size": 2, "id_as_label": false}, {"uid": "Gimli", "label": "Gimli: 11", "size": 27.0, "color": "Green", "opacity": 0.2, "coordinates": [361.55233455465395, 303.34869510493706], "label_size": 3.1, "id_as_label": false}, {"uid": "Gandalf", "label": "Gandalf: 24", "size": 53.0, "color": "Green", "opacity": 0.2, "coordinates": [368.6647462513915, 235.90552092721578], "label_size": 4.4, "id_as_label": false}, {"uid": "Frodo", "label": "Frodo: 4", "size": 13.0, "color": "Green", "opacity": 0.2, "coordinates": [357.36463622540157, 259.5266993326391], "label_size": 2.4, "id_as_label": false}, {"uid": "Gollum", "label": "Gollum: 4", "size": 13.0, "color": "Green", "opacity": 0.2, "coordinates": [330.3089500609288, 210.31143282316305], "label_size": 2.4, "id_as_label": false}, {"uid": "Sam", "label": "Sam", "size": 20.0, "color": "Red", "opacity": 0.2, "coordinates": [392.0714393884919, 239.57781273564228], "label_size": 2, "id_as_label": false}, {"uid": "Boromir", "label": "Boromir: 3", "size": 11.0, "color": "Green", "opacity": 0.2, "coordinates": [318.19436397680784, 259.65285505242616], "label_size": 2.3, "id_as_label": false}, {"uid": "Peregrin", "label": "Peregrin: 1", "size": 7.0, "color": "Green", "opacity": 0.2, "coordinates": [333.4960639318184, 269.0114948887232], "label_size": 2.1, "id_as_label": false}, {"uid": "Merry", "label": "Merry: 13", "size": 31.0, "color": "Green", "opacity": 0.2, "coordinates": [342.3893919148446, 294.494297984809], "label_size": 3.3, "id_as_label": false}, {"uid": "Pippin", "label": "Pippin: 4", "size": 13.0, "color": "Green", "opacity": 0.2, "coordinates": [328.1966725265788, 305.2064603800136], "label_size": 2.4, "id_as_label": false}, {"uid": "Legolas", "label": "Legolas: 3", "size": 11.0, "color": "Green", "opacity": 0.2, "coordinates": [384.09516658916027, 292.02437030483134], "label_size": 2.3, "id_as_label": false}, {"uid": "C\u00edrdan", "label": "C\u00edrdan", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordina
